# %%
import pandas as pd
import geopandas as gpd
import matplotlib
# Out:
# C:\Users\dante\AppData\Local\Temp\ipykernel_3092\3074727283.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
shelters = gpd.read_file("data/shelters.geojson")
shelters = shelters.astype({'NEIGHBOURH' : 'int'})
shelters.plot(kind="bar", x = "NAME", y = "NEIGHBOURH")
# Out:
# <Axes: xlabel='NAME'>

# %%
shelters.plot()
# Out:
# <Axes: >

# %%
fmbd = gpd.read_file('data/Former Municipality Boundaries Data.geojson')
fmbd.explore()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\dante\msa-2024-internship\tmp\venv\Lib\site-packages\geopandas\explore.py:280, in _explore(df, column, cmap, color, m, tiles, attr, tooltip, popup, highlight, categorical, legend, scheme, k, vmin, vmax, width, height, categories, classification_kwds, control_scale, marker_type, marker_kwds, style_kwds, highlight_kwds, missing_kwds, tooltip_kwds, popup_kwds, legend_kwds, map_kwds, **kwargs)
#     279 try:
# --> 280     import branca as bc
#     281     import folium
#
# ModuleNotFoundError: No module named 'branca'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 fmbd = gpd.read_file('data/Former Municipality Boundaries Data.geojson')
# ----> 2 fmbd.explore()
#
# File c:\Users\dante\msa-2024-internship\tmp\venv\Lib\site-packages\geopandas\geodataframe.py:2113, in GeoDataFrame.explore(self, *args, **kwargs)
#    2111 @doc(_explore)
#    2112 def explore(self, *args, **kwargs):
# -> 2113     return _explore(self, *args, **kwargs)
#
# File c:\Users\dante\msa-2024-internship\tmp\venv\Lib\site-packages\geopandas\explore.py:296, in _explore(df, column, cmap, color, m, tiles, attr, tooltip, popup, highlight, categorical, legend, scheme, k, vmin, vmax, width, height, categories, classification_kwds, control_scale, marker_type, marker_kwds, style_kwds, highlight_kwds, missing_kwds, tooltip_kwds, popup_kwds, legend_kwds, map_kwds, **kwargs)
#     293         from matplotlib import cm
#     295 except (ImportError, ModuleNotFoundError):
# --> 296     raise ImportError(
#     297         "The 'folium', 'matplotlib' and 'mapclassify' packages are required for "
#     298         "'explore()'. You can install them using "
#     299         "'conda install -c conda-forge folium matplotlib mapclassify' "
#     300         "or 'pip install folium matplotlib mapclassify'."
#     301     )
#     303 # xyservices is an optional dependency
#     304 try:
#
# ImportError: The 'folium', 'matplotlib' and 'mapclassify' packages are required for 'explore()'. You can install them using 'conda install -c conda-forge folium matplotlib mapclassify' or 'pip install folium matplotlib mapclassify'.
